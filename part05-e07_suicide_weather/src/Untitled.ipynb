# %%
import pandas as pd

# %%
pd.DataFrame(pd.read_html('List_of_countries_by_average_yearly_temperature.html')[0]).set_index('Country')
# Out:
#                                  Average yearly temperature (1961–1990, degrees Celsius)
# Country
# Burkina Faso                                                                  28.25
# Mali                                                                          28.25
# Kiribati                                                                      28.20
# Djibouti                                                                      28.00
# Tuvalu                                                                        28.00
# Senegal                                                                       27.85
# Mauritania                                                                    27.65
# Maldives                                                                      27.65
# Palau                                                                         27.60
# Benin                                                                         27.55
# ...
